# %% [markdown]
# ## IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
pd.set_option('display.max_columns', None)

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset4/main/zomato.csv', encoding= 'latin-1')
df1
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df1.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df1.shape
# Out:
# (9551, 21)

# %%
df_country= pd.read_excel('C:\\Users\\Aishwarya\\OneDrive\\Documents\\CountryCode.xlsx')
df_country
# Out:
#     Country Code         Country
# 0              1           India
# 1             14       Australia
# 2             30          Brazil
# 3             37          Canada
# 4             94       Indonesia
# 5            148     New Zealand
# 6            162     Phillipines
# 7            166           Qatar
# 8            184       Singapore
# 9            189    South Africa
# 10           191       Sri Lanka
# 11           208          Turkey
# 12           214             UAE
# 13           215  United Kingdom
# 14           216   United States

# %%
df_country.head()
# Out:
#    Country Code    Country
# 0             1      India
# 1            14  Australia
# 2            30     Brazil
# 3            37     Canada
# 4            94  Indonesia

# %%
data= pd.merge(df1, df_country, on= 'Country Code', how= 'left')

# %%
data.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
data.shape
# Out:
# (9551, 22)

# %%
# Checking Uniques values
data.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# Country                   15
# dtype: int64

# %% [markdown]
# ## EDA

# %%
data.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# Country                 0
# dtype: int64

# %%
# Visualizing the null values
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## UNIVARIATE ANALYSIS

# %%
sns.countplot(x= 'Country Code', data= data)
plt.show()

# %%
sns.countplot(x= 'Price range', data= data)
plt.show()

# %% [markdown]
# * We can see that Price range of 1 has max price range followed by 2.
# * All Price range are decreasing in order.

# %%
sns.countplot(y= 'Currency', data= data)
plt.show()

# %% [markdown]
# * We can see that Indian Rupees is most used currency, it means taht zomato has main business in India followed by Dollar.
# * Remaining all has no such use, it means zomato is not functioning in the countries like India.

# %%
sns.countplot(x= 'Has Table booking', data= data)
plt.show()

# %% [markdown]
# Zomato has not provided the table booking. But in some olaces it provides table booking.

# %%
sns.countplot(x= 'Has Online delivery', data= data)
plt.show()

# %% [markdown]
# * Most of the places has no online delivery available.
# * But in feww places, online delivery is availabel.

# %%
# The countries do have online deliveries option
a= data[data['Has Online delivery']=='Yes'].Country.value_counts()

# %%
a.plot.pie(autopct= '%1.1f%%')
plt.title('Country has Online Delivery')
plt.show()

# %% [markdown]
# * We can see, India has 98.9% online delivery availabel but UAE has only 1.1% online delivery.
# * But rest of all countries haven't online delivery.

# %%
sns.countplot(x= 'Is delivering now', data= data)
plt.show()

# %% [markdown]
# Most of the places has not available delivery now system.

# %%
plt.figure(figsize=(15,7))
sns.countplot(x= 'Aggregate rating', data= data)
plt.show()

# %% [markdown]
# * Most of the customer has given 0 aggregate rating than others.
# * 3.1 and 3.2 is most given rating after 0 aggregate rating.

# %%
sns.countplot(x= 'Rating color', data= data)
plt.show()

# %% [markdown]
# * We can see, orange is most used color for rating followed by white.
# * Red color are less used for rating, it means no one dislikes the food delivered by zomato.

# %%
sns.countplot(x= 'Rating text', data= data)
plt.show()

# %% [markdown]
# * In rating text, avg is the most used test followed by good.
# * But some of customers are not rated the zomato service, very few customers gives poor rating.

# %%
plt.figure(figsize=(20,5))
sns.countplot(x= 'Country', data= data)
plt.show()

# %% [markdown]
# * As we have observed before that Indian currency is most used. It's because India has the most Zomato business do followed by USA.
# * Rest of all the countries, zomato is not giving service as in India they gives.

# %%
city_values= data.City.value_counts().values
city_labels= data.City.value_counts().index

# %%
plt.pie(city_values[:5], labels= city_labels[:5], autopct= '%1.2f%%')
plt.show()

# %%
# Finding top 10 Cuisine

cuisin_val= data.Cuisines.value_counts().values
cuisin_label= data.Cuisines.value_counts().index

# %%
plt.pie(cuisin_val[:10], labels= cuisin_label[:10], autopct= '%1.2f%%')
plt.show()

# %%
# Finding top 10 Location

val= data.Locality.value_counts().values
label= data.Locality.value_counts().index

# %%
plt.pie(val[:10], labels= label[:10], autopct= '%1.2f%%')
plt.show()

# %%
sns.distplot(data['Average Cost for two'])
plt.show()

# %% [markdown]
# We can see that 50% restaurant are affordable.

# %% [markdown]
# ## BIVARIATE ANALYSIS

# %%
plt.figure(figsize=(15,6))
df_good= data.sort_values(by= "Average Cost for two", ascending= False)
sns.barplot(x= "Country", y= "Average Cost for two", data= df_good)
plt.show()

# %% [markdown]
# * We can see, Indonesia has high Average cost for two.

# %%
plt.figure(figsize=(20,6))
df_good= data.sort_values(by= "Average Cost for two", ascending= False).iloc[0:10]
sns.barplot(x= "Restaurant Name", y= "Average Cost for two", data= df_good)
plt.show()

# %% [markdown]
# * These are the top 10 restaurant's name, where Avg cost for two is lower than others.

# %%
df_good= data.sort_values(by= "Average Cost for two", ascending= False).iloc[0:10]
sns.barplot(x= "City", y= "Average Cost for two", data= df_good)
plt.show()

# %% [markdown]
# * These are the top cities, where has high Avg cost for two in which Jakarta is higher followed by Tangerang City.

# %%
sns.boxplot(x= 'Has Online delivery', y= 'Votes', data= data)
plt.title('Has Online delivery VS Votes')
plt.show()

# %% [markdown]
# * Restaurants accepting online orders tend to get more votes from customers as there is a rating option poping up after each other through zomato application.

# %%
data.groupby('Restaurant Name')['Aggregate rating'].mean().nlargest(10).plot.bar()
plt.show()

# %% [markdown]
# * These are the top 10 restaurant name, where most of the customers gives good aggregate rating.
# * In which Atlanta is top among the others.

# %%
sns.boxplot(x= 'Has Online delivery', y= 'Average Cost for two', data= data)
plt.title('Has Online delivery VS Average Cost for two')
plt.show()

# %% [markdown]
# * Average cost for two has not affected by online delivery system.

# %%
data.groupby('Restaurant Name')['Votes'].mean().nlargest(10).plot.bar()
plt.show()

# %% [markdown]
# * We can see, top 10 restaurant on basis of the customer's votes.

# %%
sns.scatterplot(x= 'Average Cost for two', y= 'Longitude', data= data)
plt.show()

# %%
sns.scatterplot(x= 'Average Cost for two', y= 'Latitude', data= data)
plt.show()

# %%
rating= data.groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index().rename(columns= {0:'Rating count'})

# %%
plt.figure(figsize=(12,6))
sns.barplot(x= 'Aggregate rating', y= 'Rating count', data= rating)
plt.show()

# %% [markdown]
# * When rating is in between 4.5 to 4.9 -> Excellent
# * When rating is in between 4.0 to 3.4 -> Very Good
# * When rating is in between 3.5 to 3.9 -> Good
# * When rating is in between 2.5 to 2.9 -> Average
# * When rating is in between 2.0 to 3.4 -> Poor
# * And zero(0) rating given by many people.

# %%
plt.figure(figsize=(10,6))
df_ggod= data.sort_values(by= "Latitude", ascending= False).iloc[0:10,:]
sns.barplot(y= "Restaurant Name", x= "Latitude", data= df_good)
plt.show()

# %% [markdown]
# * We can see that by Latitude, the kitchen has highest Latitude, which means at high latitude criteria, it is in top.
# * We can see, all top 10 restaurant name, where they are generally lies in nearly same latitude.

# %%
sns.barplot(x= 'Price range', y= 'Average Cost for two', data= data)
plt.show()

# %% [markdown]
# Many restaurants are having as price range 3.

# %%
sns.barplot(x= 'Rating text', y= 'Average Cost for two', data= data)
plt.show()

# %% [markdown]
# Whose having as rating text Excellent those restaurants are having high avg cost for two.

# %%
plt.figure(figsize=(12,6))
sns.barplot(x= 'Aggregate rating', y= 'Rating text', data= rating)
plt.show()

# %%
# Finding the countries that has given 0 rating
data[data['Rating color']== 'White'].groupby(['Aggregate rating', 'Country']).size().reset_index()
# Out:
#    Aggregate rating         Country     0
# 0               0.0          Brazil     5
# 1               0.0           India  2139
# 2               0.0  United Kingdom     1
# 3               0.0   United States     3

# %%
Delhi= data[(data.City == 'New Delhi')]
top_locality= Delhi.Locality.value_counts().head(10)

plt.figure(figsize=(12,6))
sns.countplot(y= "Locality", hue= "Has Online delivery", data= Delhi[Delhi.Locality.isin(top_locality.index)])

sns.countplot(y= "Locality", hue="Has Online delivery", data=Delhi[Delhi.Locality.isin(top_locality.index)])

plt.title('Restaurants Online Delivery')
plt.show()

# %% [markdown]
# * We can see, most of the places have no online delivery option or online order system.
# * But Malviya Nagar is top among the restaurant whose having online order or online delivery.

# %%
sns.countplot(x= 'Has Online delivery', hue= 'Has Table booking', data= data)
plt.show()

# %% [markdown]
# * We can see, those are not providing online delivery they also have less table booking, but it does have any impact on business because most of the restaurant has not provided online delivery.

# %%
sns.countplot(x= 'Rating color', hue= 'Price range', data= data)
plt.show()

# %%
sns.scatterplot(x= 'Votes', y= 'Average Cost for two', data= data)
plt.show()

# %% [markdown]
# * Votes has no linear relationship with Avg Cost for two.
# * But upto 2000 Votes, avg cpst for two has some linear relationship with votes.

# %%
sns.scatterplot(x= 'Votes', y= 'Aggregate rating', data= data)
plt.show()

# %% [markdown]
# * There is no direct linear relationship with each others.
# * But after 2 rating, there is a little linear relationship.

# %% [markdown]
# ## MULTIVARIATE ANALYSIS

# %%
plt.figure(figsize=(10,7))
sns.scatterplot(x= 'Aggregate rating', y= 'Average Cost for two', hue= 'Has Online delivery', data=data)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.barplot(x= 'Aggregate rating', y= 'Rating count', hue= 'Rating color', data=rating, palette= ['b','r','orange','yellow','g','darkgreen'])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.scatterplot(x= "Country", y= "Average Cost for two", hue= "Has Online delivery", data=data)
plt.show()

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(x= "Average Cost for two", y= "Aggregate rating", hue= 'Price range', data= Delhi)

plt.xlabel("Average Cost for two")
plt.ylabel("Aggregate rating")
plt.title('Rating VS Cost for Two')
plt.show()

# %% [markdown]
# I observe that there is no linear relationship between price and rating. For instance, restaurants with good rating (4-5) have restaurants with all the price range and spread across the entire X axis.

# %%
sns.scatterplot(x= 'Votes', y= 'Aggregate rating', hue= "Has Online delivery", data=data)
plt.show()

# %% [markdown]
# * We can see, many restaurants are having more than 4 rating and they also have online delivery.
# * But many restaurants don't have online deliveries and they have good ratings too.

# %% [markdown]
# ### ENCODING THE DATAFRAME

# %%
data.drop(columns=['Restaurant ID', 'Locality Verbose'], axis=1, inplace= True)

# %%
from sklearn.preprocessing import LabelEncoder

le= LabelEncoder()

# %%
for col in data[data.columns[data.dtypes == 'object']]:
    data[col]= le.fit_transform(data[col])

# %%
data.head()
# Out:
#    Restaurant Name  Country Code  City  Address  Locality   Longitude  \
# 0             3749           162    73     8685       171  121.027535
# 1             3173           162    73     6055       593  121.014101
# 2             2897           162    75     4684       308  121.056831
# 3             4707           162    75     8690       862  121.056475
# 4             5523           162    75     8689       862  121.057508
#
#     Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0  14.565443       920                  1100         0                  1
# 1  14.553708      1111                  1200         0                  1
# 2  14.581404      1671                  4000         0                  1
# 3  14.585318      1126                  1500         0                  0
# 4  14.584450      1122                  1500         0                  1
#
#    Has Online delivery  Is delivering now  Switch to order menu  Price range  \
# ...

# %%
data.describe()
# Out:
#        Restaurant Name  Country Code         City      Address     Locality  \
# count      9551.000000   9551.000000  9551.000000  9551.000000  9551.000000
# mean       3653.204586     18.365616    78.301434  4542.439430   658.128468
# std        2142.917876     56.750546    23.198915  2565.717005   315.866515
# min           0.000000      1.000000     0.000000     0.000000     0.000000
# 25%        1777.500000      1.000000    76.000000  2323.500000   381.000000
# 50%        3595.000000      1.000000    88.000000  4610.000000   696.000000
# 75%        5485.500000      1.000000    88.000000  6746.500000   921.000000
# max        7445.000000    216.000000   140.000000  8917.000000  1207.000000
#
#          Longitude     Latitude    Cuisines  Average Cost for two  \
# count  9551.000000  9551.000000  9551.00000           9551.000000
# mean     64.126574    25.854381   989.95079           1199.210763
# std      41.467058    11.007935   514.72354          16121.183073
# ...

# %% [markdown]
# ## CORRELATION

# %%
data.corr()['Average Cost for two'].sort_values()
# Out:
# Latitude               -0.111088
# Rating color           -0.049970
# City                   -0.028838
# Has Online delivery    -0.018974
# Locality               -0.012136
# Country                -0.004034
# Is delivering now      -0.001862
# Cuisines                0.005755
# Has Table booking       0.007758
# Restaurant Name         0.019241
# Address                 0.022749
# Rating text             0.031439
# Country Code            0.043225
# Currency                0.045615
# Longitude               0.045891
# Aggregate rating        0.051792
# Votes                   0.067783
# Price range             0.075083
# Average Cost for two    1.000000
# Switch to order menu         NaN
# Name: Average Cost for two, dtype: float64

# %%
plt.figure(figsize=(15,10))
sns.heatmap(data.corr(), annot= True, fmt= '.2f')
plt.show()

# %%
# Visualising correlation of features and label column
plt.figure(figsize=(20,8))
data.corr()['Average Cost for two'].sort_values(ascending= False).drop(['Average Cost for two']).plot(kind= 'bar', color= 'c')

plt.xlabel('Features', fontsize=15)
plt.ylabel('Average Cost for two', fontsize=15)
plt.title('Correlation', fontsize=18)
plt.show()

# %% [markdown]
# * The Price range, Votes and Aggregate rating have the highest positive correlation with Average Cost for two.
# * Switch to order menu, Longitude abd rating color have the highest negative correlation with Average Cost for two.

# %% [markdown]
# ### Checking the Distribution of the Data

# %%
data.shape
# Out:
# (9551, 20)

# %%
plt.figure(figsize=(25,30))
plotnumber=1

for column in data:
    if plotnumber <=20:
        ax= plt.subplot(5,4,plotnumber)
        sns.distplot(data[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %%
data.skew()
# Out:
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253554
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.305484
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %% [markdown]
# ### Checking Outliers

# %%
plt.figure(figsize=(25,30))
plotnumber=1

for column in data:
    if plotnumber <=20:
        ax= plt.subplot(5,4,plotnumber)
        sns.boxplot(data= data[column])
        plt.xlabel(column, fontsize=20)
    plotnumber +=1
plt.show()

# %% [markdown]
# ## Removing Outliers

# %%
data.head()
# Out:
#    Restaurant Name  Country Code  City  Address  Locality   Longitude  \
# 0             3749           162    73     8685       171  121.027535
# 1             3173           162    73     6055       593  121.014101
# 2             2897           162    75     4684       308  121.056831
# 3             4707           162    75     8690       862  121.056475
# 4             5523           162    75     8689       862  121.057508
#
#     Latitude  Cuisines  Average Cost for two  Currency  Has Table booking  \
# 0  14.565443       920                  1100         0                  1
# 1  14.553708      1111                  1200         0                  1
# 2  14.581404      1671                  4000         0                  1
# 3  14.585318      1126                  1500         0                  0
# 4  14.584450      1122                  1500         0                  1
#
#    Has Online delivery  Is delivering now  Switch to order menu  Price range  \
# ...

# %% [markdown]
# ## ZSCORE

# %%
from scipy.stats import zscore

zs= zscore(data[['Average Cost for two', 'Votes']]) # Only removing outliers from continuous data
abs_zs= np.abs(zs)

filtering_entry= (abs_zs <3).all(axis=1)
df= data[filtering_entry]

# %%
df.shape
# Out:
# (9362, 20)

# %%
data.shape
# Out:
# (9551, 20)

# %% [markdown]
# ### Percentage of Dataloss

# %%
data_loss= ((9551 - 9362)/9551*100)
print(data_loss, '%')
# Out:
# 1.978850382158936 %

# %% [markdown]
# ## Checking Multicollinearity

# %%
x= df.drop(columns= ['Average Cost for two'], axis=1)
y= df['Average Cost for two']

# %% [markdown]
# ## STANDARD SCALER

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss= StandardScaler()
scaled_X= ss.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif= pd.DataFrame()
vif["Features"]= x.columns
vif['vif']= [variance_inflation_factor(scaled_X, i) for i in range(scaled_X.shape[1])]
vif
# Out:
#                 Features        vif
# 0        Restaurant Name   1.008700
# 1           Country Code  48.278786
# 2                   City   1.081831
# 3                Address   1.106130
# 4               Locality   1.068078
# 5              Longitude   5.031289
# 6               Latitude   3.037873
# 7               Cuisines   1.043922
# 8               Currency   1.294013
# 9      Has Table booking   1.482431
# 10   Has Online delivery   1.168622
# 11     Is delivering now   1.014266
# 12  Switch to order menu        NaN
# 13           Price range   1.949610
# 14      Aggregate rating   1.947962
# 15          Rating color   1.221294
# 16           Rating text   1.426143
# 17                 Votes   1.613811
# 18               Country  66.489679

# %% [markdown]
# * If VIF>10, which means Multicollinearity is present.

# %%
# Dropping columns which has multicollinearity
df.drop(columns= ['Country Code', 'Switch to order menu', 'Country'], axis=1, inplace= True)

# %%
df.shape
# Out:
# (9362, 17)

# %%
x= df.drop(columns= ['Average Cost for two'], axis=1)
y= df['Average Cost for two']

# %% [markdown]
# ### Selecting KBest Features

# %%
from sklearn.feature_selection import SelectKBest, f_classif

# %%
kbest= SelectKBest(score_func= f_classif, k= 'all')
fit= kbest.fit(x,y)
dfscores= pd.DataFrame(fit.scores_)
dfcolumns= pd.DataFrame(x.columns)

# %%
fit= kbest.fit(x,y)
dfscores= pd.DataFrame(fit.scores_)
dfcolumns= pd.DataFrame(x.columns)
dfcolumns.head()

featureScores= pd.concat([dfcolumns, dfscores], axis=1)
featureScores.columns= ['Features', 'Score']
print(featureScores.nlargest(35, 'Score'))
# Out:
#                Features       Score
# 11          Price range  418.202989
# 4             Longitude  142.353602
# 8     Has Table booking   80.635590
# 7              Currency   29.041295
# 15                Votes   25.818126
# 12     Aggregate rating   22.275744
# 5              Latitude   15.805349
# 9   Has Online delivery   11.752010
# 2               Address    7.795143
# 14          Rating text    7.144425
# 1                  City    4.863372
# 13         Rating color    4.044857
# 6              Cuisines    3.786064
# 3              Locality    3.379470
# 10    Is delivering now    2.063234
# 0       Restaurant Name    1.358221

# %%
x_best= x.drop(columns= ['Restaurant Name', 'Is delivering now']).copy()

# %%
# Data skewness before removing
data.skew()
# Out:
# Restaurant Name          0.044637
# Country Code             3.043965
# City                    -1.193777
# Address                 -0.040407
# Locality                -0.253554
# Longitude               -2.807328
# Latitude                -3.081635
# Cuisines                -0.305484
# Average Cost for two    35.477915
# Currency                 2.858093
# Has Table booking        2.321100
# Has Online delivery      1.114620
# Is delivering now       16.673412
# Switch to order menu     0.000000
# Price range              0.889618
# Aggregate rating        -0.954130
# Rating color             0.046009
# Rating text              0.431408
# Votes                    8.807637
# Country                  3.312721
# dtype: float64

# %%
# Data skewness after removing

from sklearn.preprocessing import power_transform
x= power_transform(x_best, method= 'yeo-johnson')

# %%
trans= pd.DataFrame(x)

# %%
trans.skew()
# Out:
# 0    -0.198500
# 1    -0.302620
# 2    -0.306525
# 3    -0.795230
# 4    -0.259015
# 5    -0.382346
# 6     0.447069
# 7     2.382516
# 8     1.120081
# 9     0.197391
# 10   -0.615772
# 11   -0.100142
# 12   -0.055331
# 13   -0.021285
# dtype: float64

# %%
x= ss.fit_transform(x)
x
# Out:
# array([[-0.40644576,  1.47370479, -1.56895768, ..., -2.26885617,
#         -0.20420612,  1.30223393],
#        [-0.40644576,  0.61835876, -0.20264175, ..., -2.26885617,
#         -0.20420612,  1.65627302],
#        [-0.310708  ,  0.13463254, -1.11660629, ..., -1.38742706,
#          1.51689551,  1.21890769],
#        ...,
#        [ 3.88657629,  0.58789144, -0.32621295, ...,  1.32393817,
#          0.39794913,  1.71976831],
#        [ 3.88657629,  0.58823442, -0.32621295, ..., -1.38742706,
#          1.51689551,  1.8967675 ],
#        [ 3.88657629, -0.0228778 ,  0.04024675, ..., -1.38742706,
#          1.51689551,  1.65627302]])

# %% [markdown]
# ## MODEL BUILDING

# %%
from sklearn.model_selection import train_test_split, RandomizedSearchCV
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %% [markdown]
# ## LINEAR REGRESSION

# %%
# Finding Best Random State
maxAccu=0
maxRS=0

for i in range(1,1000):
    X_train, X_test, y_train, y_test= train_test_split(x,y, test_size=0.3, random_state=i)
    lr= LinearRegression()
    lr.fit(X_train, y_train)
    pred= lr.predict(X_test)
    r2= r2_score(y_test, pred)
    if r2>maxAccu:
        maxAccu= r2
        maxRS=i
        
print("Best R2 Score is", maxAccu, "on Random State", maxRS)
# Out:
# Best R2 Score is 0.587795143549694 on Random State 970

# %%
X_train, X_test, y_train, y_test= train_test_split(x,y,train_size=0.7, test_size=0.3, random_state=970)

# %%
regressors= {'Linear Regression': LinearRegression(),}

results= pd.DataFrame(columns= ['MAE', 'MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model= func.fit(X_train, y_train)
    pred= model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                         np.round(mean_squared_error(y_test,pred),3),
                         np.sqrt(mean_squared_error(y_test,pred)),
                         np.round(r2_score(y_test,pred),3)]

# %%
results
# Out:
#                        MAE         MSE        RMSE  R2-score
# Linear Regression  214.432  130880.344  361.773885     0.588

# %% [markdown]
# ## Cross Validation for Linear Regression

# %%
y_pred= lr.predict(X_test)
from sklearn.model_selection import cross_val_score
lss= r2_score(y_test, y_pred)

# %%
for j in range(4,10):
    isscross= cross_val_score(lr,x,y,cv=j)
    lsc= isscross.mean()
    print("At cv:", j)
    print('Cross Validation Score is:', lsc*100)
    print('Accuracy Score is:', lss*100)
    print('\n')
# Out:
# At cv: 4
# Cross Validation Score is: 24.207206131735195
# Accuracy Score is: 59.00890984601765
#
#
# At cv: 5
# Cross Validation Score is: 4.250227605243131
# Accuracy Score is: 59.00890984601765
#
#
# At cv: 6
# Cross Validation Score is: 8.493866667348797
# Accuracy Score is: 59.00890984601765
#
#
# At cv: 7
# Cross Validation Score is: 3.146071273103005
# Accuracy Score is: 59.00890984601765
#
#
# At cv: 8
# Cross Validation Score is: -0.35845581915559255
# Accuracy Score is: 59.00890984601765
#
#
# At cv: 9
# Cross Validation Score is: -5.6264684335894515
# Accuracy Score is: 59.00890984601765

# %%
lsscore_selected= cross_val_score(lr,x,y,cv=4).mean()
print("The cv score is: ", lsscore_selected, "\nThe Accuracy Score is: ", lss)
# Out:
# The cv score is:  0.24207206131735196
# The Accuracy Score is:  0.5900890984601765

# %% [markdown]
# ## RANDOM FOREST REGRESSOR

# %%
# Finding Best Random State
maxAccu=0
maxRS=0

for i in range(1,1000):
    X_train, X_test, y_train, y_test= train_test_split(x,y, test_size=0.3, random_state=i)
    rf= RandomForestRegressor()
    rf.fit(X_train, y_train)
    pred= rf.predict(X_test)
    r2= r2_score(y_test, pred)
    if r2>maxAccu:
        maxAccu= r2
        maxRS=i
        
print("Best r2 Score is", maxAccu, "on Random State", maxRS)
# Out:
# Best r2 Score is 0.9115720108225495 on Random State 420

# %%
X_train, X_test, y_train, y_test= train_test_split(x,y,train_size=0.7, test_size=0.3, random_state=420)

# %%
regressors= {'Random Forest Regressor': RandomForestRegressor(),}

results= pd.DataFrame(columns= ['MAE', 'MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model= func.fit(X_train, y_train)
    pred= model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                         np.round(mean_squared_error(y_test,pred),3),
                         np.sqrt(mean_squared_error(y_test,pred)),
                         np.round(r2_score(y_test,pred),3)]

# %%
results
# Out:
#                             MAE        MSE        RMSE  R2-score
# Random Forest Regressor  98.547  28879.026  169.938301     0.908

# %% [markdown]
# ## Cross Validation for Random Forest Regressor

# %%
y_pred= rf.predict(X_test)
from sklearn.model_selection import cross_val_score
lss= r2_score(y_test, y_pred)

# %%
for j in range(4,10):
    isscross= cross_val_score(rf,x,y,cv=j)
    lsc= isscross.mean()
    print("At cv:", j)
    print('Cross Validation Score is:', lsc*100)
    print('Accuracy Score is:', lss*100)
    print('\n')
# Out:
# At cv: 4
# Cross Validation Score is: 60.85491834109342
# Accuracy Score is: 96.10043681558163
#
#
# At cv: 5
# Cross Validation Score is: 43.710275392559375
# Accuracy Score is: 96.10043681558163
#
#
# At cv: 6
# Cross Validation Score is: 48.16406333944494
# Accuracy Score is: 96.10043681558163
#
#
# At cv: 7
# Cross Validation Score is: 43.324448023535716
# Accuracy Score is: 96.10043681558163
#
#
# At cv: 8
# Cross Validation Score is: 40.591588535201836
# Accuracy Score is: 96.10043681558163
#
#
# At cv: 9
# Cross Validation Score is: 38.339912137276634
# Accuracy Score is: 96.10043681558163

# %%
lsscore_selected= cross_val_score(rf,x,y,cv=4).mean()
print("The cv score is: ", lsscore_selected, "\nThe Accuracy Score is: ", lss)
# Out:
# The cv score is:  0.589878933047385
# The Accuracy Score is:  0.9610043681558162

# %% [markdown]
# ## GRADIENT BOOSTING REGRESSOR

# %%
# Finding Best Random State
maxAccu=0
maxRS=0

for i in range(1,1000):
    X_train, X_test, y_train, y_test= train_test_split(x,y, test_size=0.3, random_state=i)
    gb= GradientBoostingRegressor()
    gb.fit(X_train, y_train)
    pred= gb.predict(X_test)
    r2= r2_score(y_test, pred)
    if r2>maxAccu:
        maxAccu= r2
        maxRS=i
        
print("Best r2 Score is", maxAccu, "on Random State", maxRS)
# Out:
# Best r2 Score is 0.8905001005213676 on Random State 891

# %%
X_train, X_test, y_train, y_test= train_test_split(x,y,train_size=0.7, test_size=0.3, random_state=891)

# %%
regressors= {'Gradient Boosting Regressor': GradientBoostingRegressor(),}

results= pd.DataFrame(columns= ['MAE', 'MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model= func.fit(X_train, y_train)
    pred= model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                         np.round(mean_squared_error(y_test,pred),3),
                         np.sqrt(mean_squared_error(y_test,pred)),
                         np.round(r2_score(y_test,pred),3)]

# %%
results
# Out:
#                                  MAE        MSE        RMSE  R2-score
# Gradient Boosting Regressor  114.443  37242.514  192.983197     0.891

# %% [markdown]
# ### Cross Validation for Gradient Boosting Regressor

# %%
y_pred= gb.predict(X_test)
from sklearn.model_selection import cross_val_score
lss= r2_score(y_test, y_pred)

# %%
for j in range(4,10):
    isscross= cross_val_score(gb,x,y,cv=j)
    lsc= isscross.mean()
    print("At cv:", j)
    print('Cross Validation Score is:', lsc*100)
    print('Accuracy Score is:', lss*100)
    print('\n')
# Out:
# At cv: 4
# Cross Validation Score is: 68.76988918684258
# Accuracy Score is: 90.92373494656651
#
#
# At cv: 5
# Cross Validation Score is: 57.980132466120956
# Accuracy Score is: 90.92373494656651
#
#
# At cv: 6
# Cross Validation Score is: 56.982635468049324
# Accuracy Score is: 90.92373494656651
#
#
# At cv: 7
# Cross Validation Score is: 55.681523233168996
# Accuracy Score is: 90.92373494656651
#
#
# At cv: 8
# Cross Validation Score is: 55.75657133279456
# Accuracy Score is: 90.92373494656651
#
#
# At cv: 9
# Cross Validation Score is: 53.17218496507774
# Accuracy Score is: 90.92373494656651

# %%
lsscore_selected= cross_val_score(gb,x,y,cv=4).mean()
print("The cv score is: ", lsscore_selected, "\nThe Accuracy Score is: ", lss)
# Out:
# The cv score is:  0.6910177911612168
# The Accuracy Score is:  0.9092373494656651

# %% [markdown]
# ## KNEIGHBORS REGRESSOR

# %%
# Finding Best Random State
maxAccu=0
maxRS=0

for i in range(1,1000):
    X_train, X_test, y_train, y_test= train_test_split(x,y, test_size=0.3, random_state=i)
    knn= KNN()
    knn.fit(X_train, y_train)
    pred= knn.predict(X_test)
    r2= r2_score(y_test, pred)
    if r2>maxAccu:
        maxAccu= r2
        maxRS=i
        
print("Best r2 Score is", maxAccu, "on Random State", maxRS)
# Out:
# Best r2 Score is 0.7627952870214656 on Random State 358

# %%
X_train, X_test, y_train, y_test= train_test_split(x,y,train_size=0.7, test_size=0.3, random_state=358)

# %%
regressors= {'KNeighbors Regressor': KNN(),}

results= pd.DataFrame(columns= ['MAE', 'MSE', 'RMSE', 'R2-score'])

for method,func in regressors.items():
    model= func.fit(X_train, y_train)
    pred= model.predict(X_test)
    results.loc[method]= [np.round(mean_absolute_error(y_test,pred),3),
                         np.round(mean_squared_error(y_test,pred),3),
                         np.sqrt(mean_squared_error(y_test,pred)),
                         np.round(r2_score(y_test,pred),3)]

# %%
results
# Out:
#                           MAE        MSE        RMSE  R2-score
# KNeighbors Regressor  153.897  81992.524  286.343368     0.763

# %% [markdown]
# ### Cross Validation for KNN

# %%
y_pred= knn.predict(X_test)
from sklearn.model_selection import cross_val_score
lss= r2_score(y_test, y_pred)

# %%
for j in range(4,10):
    isscross= cross_val_score(knn,x,y,cv=j)
    lsc= isscross.mean()
    print("At cv:", j)
    print('Cross Validation Score is:', lsc*100)
    print('Accuracy Score is:', lss*100)
    print('\n')
# Out:
# At cv: 4
# Cross Validation Score is: 43.652628614438804
# Accuracy Score is: 79.88994606809942
#
#
# At cv: 5
# Cross Validation Score is: 32.48167330585002
# Accuracy Score is: 79.88994606809942
#
#
# At cv: 6
# Cross Validation Score is: 37.19162355927823
# Accuracy Score is: 79.88994606809942
#
#
# At cv: 7
# Cross Validation Score is: 35.05614718189994
# Accuracy Score is: 79.88994606809942
#
#
# At cv: 8
# Cross Validation Score is: 29.169372538717752
# Accuracy Score is: 79.88994606809942
#
#
# At cv: 9
# Cross Validation Score is: 27.879504598254535
# Accuracy Score is: 79.88994606809942

# %%
lsscore_selected= cross_val_score(knn,x,y,cv=4).mean()
print("The cv score is: ", lsscore_selected, "\nThe Accuracy Score is: ", lss)
# Out:
# The cv score is:  0.43652628614438804
# The Accuracy Score is:  0.7988994606809943

# %% [markdown]
# ## HYPER PARAMETER TUNING

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %%
X_train, X_test, y_train, y_test= train_test_split(x,y,train_size=0.7, test_size=0.3, random_state=595)

# %%
param= {'min_samples_split':[2,5,10],
       'min_samples_leaf':[1,3,4],
       'max_depth':[5,10,15],
       'learning_rate':[0.1,0.2,0.3],
       'n_estimators':[150,200,250],}

# %%
grd= GridSearchCV(gb, param_grid= param)
grd.fit(X_train, y_train)
print('Best Params ', grd.best_params_)
# Out:
# Best Params  {'learning_rate': 0.1, 'max_depth': 5, 'min_samples_leaf': 4, 'min_samples_split': 2, 'n_estimators': 150}

# %%
gb= GradientBoostingRegressor(learning_rate= 0.1, max_depth= 5, min_samples_leaf= 4, min_samples_split= 5, n_estimators= 150,)
gb.fit(X_train, y_train)
pred= gb.predict(X_test)
r2_score(y_test, pred)
# Out:
# 0.8910364598194708

# %% [markdown]
# ### Plot Original VS Predicted: Average Cost for Two

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test, y=y_pred)
plt.plot(y_test, y_test)
plt.xlabel('Original Average Cost for two')
plt.ylabel('Predicted Average Cost for two')
plt.show()

# %% [markdown]
# ## SAVING THE MODEL

# %%
import joblib
joblib.dump(gb, "Average_Cost_for_Two_Prediction.pkl")
# Out:
# ['Average_Cost_for_Two_Prediction.pkl']

# %% [markdown]
# ### LOADING THE MODEL

# %%
mod= joblib.load("Average_Cost_for_Two_Prediction.pkl")

# %%
print(mod.predict(x))
# Out:
# [1084.12348848 1292.61935636 3772.05046243 ...  678.64662582  672.39970064
#    75.40914135]

# %% [markdown]
# ### PREDICTION

# %%
Prediction_accuracy= pd.DataFrame({'Predictions': mod.predict(x), 'Original Values': y})
Prediction_accuracy.head(30)
# Out:
#     Predictions  Original Values
# 0   1084.123488             1100
# 1   1292.619356             1200
# 2   3772.050462             4000
# 3   2304.312469             1500
# 4   1654.463540             1500
# 5   1213.425096             1000
# 6   2142.029629             2000
# 7   2234.718212             2000
# 8   5431.185285             6000
# 9   1085.088372             1100
# 10  1046.840839              800
# 11   775.699079              900
# 12   800.838239              800
# 13   896.900754             1000
# 14   822.243020              700
# 15   773.659329              800
# 16   910.847246              850
# 17  1123.652659             1200
# 18   491.363857              600
# 19  1651.804701             1500
# 20  2880.381264             3000
# 21  1816.004028             1800
# 22    86.685308               55
# 23    17.848491               30
# 24    50.082699               45
# 25   109.679666               60
# 26    36.820018               50
# ...

# %% [markdown]
# ## MODEL BUILDING FOR PREDICTING PRICE RANGE

# %%
df.head()
# Out:
#    Restaurant Name  City  Address  Locality   Longitude   Latitude  Cuisines  \
# 0             3749    73     8685       171  121.027535  14.565443       920
# 1             3173    73     6055       593  121.014101  14.553708      1111
# 2             2897    75     4684       308  121.056831  14.581404      1671
# 3             4707    75     8690       862  121.056475  14.585318      1126
# 4             5523    75     8689       862  121.057508  14.584450      1122
#
#    Average Cost for two  Currency  Has Table booking  Has Online delivery  \
# 0                  1100         0                  1                    0
# 1                  1200         0                  1                    0
# 2                  4000         0                  1                    0
# 3                  1500         0                  0                    0
# 4                  1500         0                  1                    0
#
# ...

# %% [markdown]
# ### CHECKING MULTICOLLINEARITY

# %%
x= df.drop(columns= ['Price range'], axis=1)
y= df['Price range']

# %% [markdown]
# ## STANDARD SCALER

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss= StandardScaler()
ss_X= ss.fit_transform(x)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
vif= pd.DataFrame()

vif["Features"]= x.columns
vif['vif']= [variance_inflation_factor(ss_X, i) for i in range(ss_X.shape[1])]
vif
# Out:
#                 Features       vif
# 0        Restaurant Name  1.007167
# 1                   City  1.073697
# 2                Address  1.098924
# 3               Locality  1.067977
# 4              Longitude  1.436619
# 5               Latitude  1.056335
# 6               Cuisines  1.039253
# 7   Average Cost for two  1.741087
# 8               Currency  1.171581
# 9      Has Table booking  1.596766
# 10   Has Online delivery  1.154632
# 11     Is delivering now  1.014095
# 12      Aggregate rating  1.773284
# 13          Rating color  1.206737
# 14           Rating text  1.360286
# 15                 Votes  1.546769

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, accuracy_score, roc_auc_score
from sklearn.model_selection import train_test_split, cross_val_score

# %%
from sklearn.preprocessing import power_transform
x= power_transform(x, method= 'yeo-johnson')

# %%
# Transform my dataset into standard normal distribution

from sklearn.preprocessing import StandardScaler
sc= StandardScaler()
x= sc.fit_transform(x)
x
# Out:
# array([[ 0.15320122, -0.40644576,  1.47370479, ..., -2.26885617,
#         -0.20420612,  1.30223393],
#        [-0.10300615, -0.40644576,  0.61835876, ..., -2.26885617,
#         -0.20420612,  1.65627302],
#        [-0.23099771, -0.310708  ,  0.13463254, ..., -1.38742706,
#          1.51689551,  1.21890769],
#        ...,
#        [-0.15079956,  3.88657629,  0.58789144, ...,  1.32393817,
#          0.39794913,  1.71976831],
#        [-1.61804193,  3.88657629,  0.58823442, ..., -1.38742706,
#          1.51689551,  1.8967675 ],
#        [ 1.50177812,  3.88657629, -0.0228778 , ..., -1.38742706,
#          1.51689551,  1.65627302]])

# %% [markdown]
# ### BALANCING THE DATA

# %%
# Balancing the data

from imblearn.over_sampling import SMOTE as sm

# %%
smt_x, smt_y= sm().fit_resample(x,y)
smt_y.value_counts()
# Out:
# 3    4437
# 4    4437
# 2    4437
# 1    4437
# Name: Price range, dtype: int64

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
# Finding Best Random State
maxAccu=0
maxRS=0

for i in range(1,1000):
    x_train, x_test, y_train, y_test= train_test_split(smt_x, smt_y, test_size=0.3, random_state=i)
    lr= LogisticRegression()
    lr.fit(x_train, y_train)
    pred= lr.predict(x_test)
    accuracy= accuracy_score(y_test, pred)
    if accuracy>maxAccu:
        maxAccu= accuracy
        maxRS=i
        
print("Best Accuracy Score is", maxAccu, "on Random State", maxRS)
# Out:
# Best Accuracy Score is 0.6766197183098591 on Random State 275

# %%
 x_train, x_test, y_train, y_test= train_test_split(smt_x, smt_y, test_size=0.3, random_state=275)

# %%
lr= LogisticRegression()
lr.fit(x_train, y_train)
y_pred= lr.predict(x_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.6766197183098591

# %% [markdown]
# ### Cross Validation for LogicticRegression

# %%
pred_lr= lr.predict(x_test)
accu= accuracy_score(y_test, pred_lr)

# %%
for j in range(4,10):
    cross= cross_val_score(lr,x,y,cv=j)
    lsc= cross.mean()
    print("At cv:", j)
    print('Cross Validation Score is:', lsc*100)
    print('Accuracy Score is:', accu*100)
    print('\n')
# Out:
# At cv: 4
# Cross Validation Score is: 78.1891733023728
# Accuracy Score is: 67.6619718309859
#
#
# At cv: 5
# Cross Validation Score is: 76.88664489985901
# Accuracy Score is: 67.6619718309859
#
#
# At cv: 6
# Cross Validation Score is: 75.87240674124082
# Accuracy Score is: 67.6619718309859
#
#
# At cv: 7
# Cross Validation Score is: 75.52009041120263
# Accuracy Score is: 67.6619718309859
#
#
# At cv: 8
# Cross Validation Score is: 75.658725466582
# Accuracy Score is: 67.6619718309859
#
#
# At cv: 9
# Cross Validation Score is: 75.32787137614227
# Accuracy Score is: 67.6619718309859

# %%
lsscore_selected= cross_val_score(lr,x,y,cv=9).mean()
print("The cv score is: ", lsscore_selected, "\nThe Accuracy Score is: ", accu)
# Out:
# The cv score is:  0.7532787137614227
# The Accuracy Score is:  0.6766197183098591

# %%
def metric_score(clf, x_train_ns, x_test, y_train_ns, y_test, train= True):
    if train:
        y_pred= clf.predict(x_train_ns)
        
        print("\n========================= Train Result ============================")
        print(f"Accuracy Score: {accuracy_score(y_train_ns, y_pred) * 100:.2f}%")
        
    elif train== False:
        pred= clf.predict(x_test)
        
        print("\n======================== Test Result =============================")
        print(f"Accuracy Score: {accuracy_score(y_test, pred) * 100:.2f}%")
        print("\n \n Test Classification Report \n", classification_report(y_test, pred, digits=2))
        print('\n Confusion Matrix: \n', confusion_matrix(y_test, pred))

# %% [markdown]
# ## RANDOM FOREST CLASSIFIER

# %%
# Finding Best Random State
maxAccu=0
maxRS=0

for i in range(1,1000):
    x_train, x_test, y_train, y_test= train_test_split(smt_x, smt_y, test_size=0.3, random_state=i)
    rfc= RandomForestClassifier()
    rfc.fit(x_train, y_train)
    pred= rfc.predict(x_test)
    accuracy= accuracy_score(y_test, pred)
    if accuracy>maxAccu:
        maxAccu= accuracy
        maxRS=i
        
print("Best Accuracy Score is", maxAccu, "on Random State", maxRS)
# Out:
# Best Accuracy Score is 0.9928638497652582 on Random State 138

# %%
 x_train, x_test, y_train, y_test= train_test_split(smt_x, smt_y, test_size=0.3, random_state=138)

# %%
rfc= RandomForestClassifier()
rfc.fit(x_train, y_train)

metric_score(rfc, x_train, x_test, y_train, y_test, train=True)
metric_score(rfc, x_train, x_test, y_train, y_test, train=False)
# Out:
# ========================= Train Result ============================
# Accuracy Score: 100.00%
#
# ======================== Test Result =============================
# Accuracy Score: 99.29%
#
#
#  Test Classification Report
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00      1343
#            2       0.99      0.99      0.99      1310
#            3       0.99      0.99      0.99      1327
#            4       1.00      1.00      1.00      1345
#
#     accuracy                           0.99      5325
#    macro avg       0.99      0.99      0.99      5325
# weighted avg       0.99      0.99      0.99      5325
#
#
#  Confusion Matrix:
#  [[1338    5    0    0]
#  [   0 1294   16    0]
#  [   0    7 1314    6]
#  [   0    0    4 1341]]

# %% [markdown]
# ### Cross Validation for Random Forest Classifier

# %%
pred_rfc= rfc.predict(x_test)
accu= accuracy_score(y_test, pred_rfc)

# %%
for j in range(4,10):
    cross= cross_val_score(rfc,x,y,cv=j)
    lsc= cross.mean()
    print("At cv:", j)
    print('Cross Validation Score is:', lsc*100)
    print('Accuracy Score is:', accu*100)
    print('\n')
# Out:
# At cv: 4
# Cross Validation Score is: 89.05254073611614
# Accuracy Score is: 99.28638497652582
#
#
# At cv: 5
# Cross Validation Score is: 84.60055968531677
# Accuracy Score is: 99.28638497652582
#
#
# At cv: 6
# Cross Validation Score is: 90.7301162962598
# Accuracy Score is: 99.28638497652582
#
#
# At cv: 7
# Cross Validation Score is: 90.76217531832305
# Accuracy Score is: 99.28638497652582
#
#
# At cv: 8
# Cross Validation Score is: 89.90938419204858
# Accuracy Score is: 99.28638497652582
#
#
# At cv: 9
# Cross Validation Score is: 89.85644145586508
# Accuracy Score is: 99.28638497652582

# %%
lsscore_selected= cross_val_score(rfc,x,y,cv=9).mean()
print("The cv score is: ", lsscore_selected, "\nThe Accuracy Score is: ", accu)
# Out:
# The cv score is:  0.897389508772794
# The Accuracy Score is:  0.9928638497652582

# %% [markdown]
# ## GRADIENT BOOSTING CLASSIFIER

# %%
# Finding Best Random State
maxAccu=0
maxRS=0

for i in range(1,1000):
    x_train, x_test, y_train, y_test= train_test_split(smt_x, smt_y, test_size=0.3, random_state=i)
    gbc= GradientBoostingClassifier()
    gbc.fit(x_train, y_train)
    pred= gbc.predict(x_test)
    accuracy= accuracy_score(y_test, pred)
    if accuracy>maxAccu:
        maxAccu= accuracy
        maxRS=i
        
print("Best Accuracy Score is", maxAccu, "on Random State", maxRS)
